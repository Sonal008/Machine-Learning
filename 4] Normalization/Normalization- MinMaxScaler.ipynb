# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('wine.csv', header=None, usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']
df.head()
# Out:
#    Class label  Alcohol  Malic acid
# 0            1    14.23        1.71
# 1            1    13.20        1.78
# 2            1    13.16        2.36
# 3            1    14.37        1.95
# 4            1    13.24        2.59

# %%
df['Class label'].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class label, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Class label  178 non-null    int64
#  1   Alcohol      178 non-null    float64
#  2   Malic acid   178 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 4.3 KB

# %%
import seaborn as sns

color_dict={1:'red', 3:'green', 2:'blue'}
sns.scatterplot(x = df['Alcohol'], y = df['Malic acid'],hue=df['Class label'],palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label', axis =1), df['Class label'], 
                                                    test_size = 0.3, random_state = 0)

# %%
print(f'X_train shape: {X_train.shape}\nX_test shape: {X_test.shape}\nY_train shape: {y_train.shape}\nY_test shape: {y_test.shape}')
# Out:
# X_train shape: (124, 2)
# X_test shape: (54, 2)
# Y_train shape: (124,)
# Y_test shape: (54,)

# %% [markdown]
# # Min-Max Scaling
# - xi-xmin/xmax-xmin

# %%
x1 = X_train['Alcohol'].iloc[0]
xmin = X_train['Alcohol'].min()
xmax = X_train['Alcohol'].max()
print('x1_new on Alcohol column:',(x1-xmin)/(xmax-xmin))
# Out:
# x1_new on Alcohol column: 0.720430107526882

# %%
from sklearn.preprocessing import MinMaxScaler

#create object 
scale = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scale.fit(X_train)

# transform train and test sets
X_train_scale = scale.transform(X_train)
X_test_scale = scale.transform(X_test)

# %%
X_train_scale = pd.DataFrame(X_train_scale, columns = X_train.columns)
X_test_scale = pd.DataFrame(X_test_scale, columns=X_test.columns)

# %%
X_train.head()
# Out:
#      Alcohol  Malic acid
# 22     13.71        1.86
# 108    12.22        1.29
# 175    13.27        4.28
# 145    13.16        3.57
# 71     13.86        1.51

# %%
X_train_scale.head()
# Out:
#     Alcohol  Malic acid
# 0  0.720430    0.203782
# 1  0.319892    0.084034
# 2  0.602151    0.712185
# 3  0.572581    0.563025
# 4  0.760753    0.130252

# %%
np.round(X_train.describe(), 2)
# Out:
#        Alcohol  Malic acid
# count   124.00      124.00
# mean     12.98        2.38
# std       0.80        1.14
# min      11.03        0.89
# 25%      12.36        1.61
# 50%      13.04        1.88
# 75%      13.64        3.25
# max      14.75        5.65

# %%
np.round(X_train_scale.describe(),2)
# Out:
#        Alcohol  Malic acid
# count   124.00      124.00
# mean      0.53        0.31
# std       0.22        0.24
# min       0.00        0.00
# 25%       0.36        0.15
# 50%       0.54        0.21
# 75%       0.70        0.50
# max       1.00        1.00

# %% [markdown]
# ## We could observe that all statistical values get affected except count
# ## Min-Max values is between 0-1

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (15,7))

# Before scaling - Alcohol
sns.kdeplot(X_train['Alcohol'], ax = ax1)
ax1.set_title('BEFORE Scaling')

# After scaling - Alcohol
sns.kdeplot(X_train_scale['Alcohol'], ax = ax2)
ax2.set_title('AFTER Scaling')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2, figsize = (15,7))

# Before scaling - Alcohol
sns.kdeplot(X_train['Malic acid'], ax = ax1)
ax1.set_title('BEFORE Scaling')

# After scaling - Alcohol
sns.kdeplot(X_train_scale['Malic acid'], ax = ax2)
ax2.set_title('AFTER Scaling')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],c=y_train)
ax1.set_title("BEFORE Scaling")

ax2.scatter(X_train_scale['Alcohol'], X_train_scale['Malic acid'],c=y_train)
ax2.set_title("AFTER Scaling")
plt.show()

# %% [markdown]
# # Observing MinMax Scaling effect on model training

# %%
from sklearn.linear_model import LogisticRegression

#create object 
lg = LogisticRegression()
lg_scale = LogisticRegression()

# %%
lg.fit(X_train,y_train)
lg_scale.fit(X_train_scale, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lg.predict(X_test)
y_pred_scale = lg_scale.predict(X_test_scale)

# %%
from sklearn.metrics import accuracy_score

print("Actual data", accuracy_score(y_test,y_pred))
print("Scaled data", accuracy_score(y_test,y_pred_scale))
# Out:
# Actual data 0.7592592592592593
# Scaled data 0.7962962962962963

# %%
df['Alcohol'].min()
# Out:
# 11.03

# %%
df['Alcohol'].max()
# Out:
# 14.83

# %% [markdown]
# # Observe Outlier in MinMax Data

# %%
# add outlier in data 

df = df.append(pd.DataFrame({'Alcohol':[40,30,20],'Malic acid':[40,25,50],'Class label':[0,1,1]}),ignore_index=True)
df.tail()
# Out:
#      Class label  Alcohol  Malic acid
# 176            3    13.17        2.59
# 177            3    14.13        4.10
# 178            0    40.00       40.00
# 179            1    30.00       25.00
# 180            1    20.00       50.00

# %%
plt.scatter(df['Alcohol'], df['Malic acid'])

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label', axis =1), df['Class label'], 
                                                    test_size = 0.3, random_state = 0)

# %%
outlier_scale = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
outlier_scale.fit(X_train)

# transform train and test sets
X_train_outlier_scale = outlier_scale.transform(X_train)
X_test_outlier_scale = outlier_scale.transform(X_test)

# %%
X_train_outlier_scale = pd.DataFrame(X_train_outlier_scale, columns=X_train.columns)
X_test_outlier_scale = pd.DataFrame(X_test_outlier_scale, columns=X_test.columns)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Alcohol'], X_train['Malic acid'])
ax1.set_title("Outlier Before")
ax2.scatter(X_train_outlier_scale['Alcohol'], X_train_outlier_scale['Malic acid'],color='red')
ax2.set_title("Outlier After")
plt.show()

# %% [markdown]
# # Hence, MinMax scaling doesn't help in case of outliers
